# %% [markdown]
# ## **Experiment 1: up-sampling & No Preprocessing**

# %% [markdown]
# ### **Get Data**

# %%
pip install qalsadi
# Out:
# Collecting qalsadi
#   Downloading qalsadi-0.4.4-py3-none-any.whl (257 kB)
#      |████████████████████████████████| 257 kB 7.6 MB/s
# Collecting pyarabic>=0.6.7
#   Downloading PyArabic-0.6.14-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 51.2 MB/s
# Collecting Arabic-Stopwords>=0.3
#   Downloading Arabic_Stopwords-0.3-py3-none-any.whl (353 kB)
#      |████████████████████████████████| 353 kB 56.2 MB/s
# Collecting naftawayh>=0.3
#   Downloading Naftawayh-0.4-py3-none-any.whl (332 kB)
#      |████████████████████████████████| 332 kB 71.7 MB/s
# Collecting arramooz-pysqlite>=0.3
#   Downloading arramooz_pysqlite-0.3-py3-none-any.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 21.2 MB/s
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from qalsadi) (0.16.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from qalsadi) (1.15.0)
# Collecting pickledb>=0.9.2
#   Downloading pickleDB-0.9.2.tar.gz (3.7 kB)
# Collecting tashaphyne>=0.3.4.1
#   Downloading Tashaphyne-0.3.4.1-py3-none-any.whl (244 kB)
#      |████████████████████████████████| 244 kB 53.3 MB/s
# Collecting alyahmor>=0.1
#   Downloading alyahmor-0.1.2-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.9 MB/s
# Collecting libqutrub>=1.2.3
#   Downloading libqutrub-1.2.4.1-py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 46.1 MB/s
# Building wheels for collected packages: pickledb
#   Building wheel for pickledb (setup.py) ... done
#   Created wheel for pickledb: filename=pickleDB-0.9.2-py3-none-any.whl size=4268 sha256=0b44021a28b611b7dcef6de4371be1d343bc4b26d338303125d794d69fcfdc6c
#   Stored in directory: /root/.cache/pip/wheels/08/34/42/9a7f94099208ce3d32638d98586a5a50f821db2fc75a3bdaae
# Successfully built pickledb
# Installing collected packages: pyarabic, tashaphyne, libqutrub, pickledb, naftawayh, arramooz-pysqlite, Arabic-Stopwords, alyahmor, qalsadi
# Successfully installed Arabic-Stopwords-0.3 alyahmor-0.1.2 arramooz-pysqlite-0.3 libqutrub-1.2.4.1 naftawayh-0.4 pickledb-0.9.2 pyarabic-0.6.14 qalsadi-0.4.4 tashaphyne-0.3.4.1

# %%
import pandas as pd
df_Spam = pd.read_excel("SpamTweets_S.xlsx")
df_Ham = pd.read_excel("HamTweets_S.xlsx")

# %%
print('Number of Spam Tweets :' ,len(df_Spam))
print('Number of Ham Tweets :' ,len(df_Ham))
# Out:
# Number of Spam Tweets : 10339
# Number of Ham Tweets : 11299

# %%
df_Spam.columns
# Out:
# Index(['OSN', 'SN', 'Tweet ID', 'Label', 'Date', 'Time', 'Date Time', 'URL',
#        'Tweet Text', 'Cleaned Text', 'User Name', 'Location',
#        'Replied Tweet ID', 'Replied Tweet User ID ', 'Replied Tweet User Name',
#        'Coordinates', 'Retweet Count', 'Favorite Count', 'Favorited'],
#       dtype='object')

# %%
df_Ham.columns
# Out:
# Index(['SN', 'OSN', 'Tweet ID', 'Label', 'Date', 'Time', 'Date Time', 'URL',
#        'Tweet Text', 'Cleaned Text', 'User Name', 'Location',
#        'Replied Tweet ID ', 'Replied Tweet User ID', 'Replied Tweet User name',
#        'Coordinates', 'Retweet Count', 'Favorite Count', 'Favorited'],
#       dtype='object')

# %%
df_Spam = df_Spam[['Cleaned Text','Label']]

# %%
df_Ham = df_Ham[['Cleaned Text','Label']]

# %%
df_Spam = df_Spam.drop_duplicates(subset="Cleaned Text")
df_Ham = df_Ham.drop_duplicates(subset="Cleaned Text")

# %%
print('Number of Spam Tweets :' ,len(df_Spam))
print('Number of Ham Tweets :' ,len(df_Ham))
# Out:
# Number of Spam Tweets : 2230
# Number of Ham Tweets : 11034

# %%
df = pd.concat([df_Spam, df_Ham])

# %%
print('Number of ALL Tweets :' ,len(df))
# Out:
# Number of ALL Tweets : 13264

# %% [markdown]
# ### **Data Preprocessing**

# %%
import qalsadi.lemmatizer
lemmer = qalsadi.lemmatizer.Lemmatizer()


def preprocess_txt(txt):
  return " ".join(lemmer.lemmatize_text(txt))
  
df['Cleaned Text2'] = df['Cleaned Text'].apply(preprocess_txt)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

text = list(df.iloc[:,:-1]["Cleaned Text"])

#Word-Level
vectorizer = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=5000)
#Char-Level
#vectorizer = TfidfVectorizer(analyzer='char', ngram_range=(2,3), max_features=5000)

vectorizer.fit(text)

print(vectorizer.vocabulary_)
print(vectorizer.idf_)
# Out:
# {'سلام': 2856, 'على': 3338, 'علاج': 3327, 'قذف': 3600, 'سريع': 2826, 'طبيعة': 3161, 'برود': 1488, 'جنس': 2153, 'نساء': 4617, 'طلب': 3183, 'تواصل': 1986, 'واتساب': 4783, 'من': 4425, 'هنا': 4764, 'صفح': 3084, 'الدكتوره': 833, 'ام': 1191, 'نايف': 4582, 'ضعف': 3136, 'انتصاب': 1242, 'الخاصه': 809, 'قطر': 3630, 'الاثاره': 458, 'اهلا': 1307, 'سهل': 2882, 'بكم': 1528, 'القذ': 996, 'ف': 3440, 'الامريكي': 619, 'الاخصائيه': 483, 'الافضل': 577, 'اصدقائي': 359, 'حي': 2340, 'صحة': 3051, 'سعيد': 2833, 'انتظار': 1244, 'ان': 1230, 'شاء': 2924, 'لها': 3902, 'تساب': 1753, 'عسل': 3294, 'منتج': 4440, 'السعاده': 871, 'حب': 2220, 'ال': 450, 'لقا': 3876, 'هنالا': 4766, 'توتر': 1991, 'بعد': 1512, 'يوم': 4982, 'حل': 2305, 'عروض': 3285, 'لسن': 3865, 'الجديده': 762, 'لكم': 3887, 'لا': 3784, 'تردي': 1730, 'زوج': 2743, 'جد': 2094, 'شباب': 2945, 'قوى': 3661, 'نشاط': 4626, 'حيوي': 2352, 'قلق': 3640, 'الاقوي': 592, 'حصر': 2273, 'راح': 2597, 'مضمون': 4283, 'بتع': 1447, 'زياد': 2749, 'وزن': 4894, 'كرش': 3724, 'او': 1311, 'ترهل': 1744, 'عن': 3358, 'نتائج': 4584, 'ميز': 4536, 'نزل': 4612, 'كيلو': 3778, 'خلال': 2416, 'الطبيعيه': 936, 'بدون': 1464, 'اي': 1337, 'اضرار': 368, 'جسم': 2124, 'دفع': 2511, 'عند': 3366, 'استلام': 307, 'نور': 4689, 'علي': 3339, 'الصفحه': 923, 'عمل': 3351, 'الرغبه': 855, 'لمح': 3896, 'دلع': 2519, 'هوس': 4772, 'غير': 3439, 'مسبق': 4200, 'ليس': 3913, 'طعم': 3172, 'لون': 3909, 'سحر': 2809, 'جنون': 2156, 'منا': 4426, 'جدا': 2095, 'تكبير': 1900, 'تطويل': 1815, 'تضخيم': 1804, 'قضيب': 3625, 'شد': 2956, 'تاخير': 1606, 'حيوان': 2351, 'منوي': 4470, 'علك': 3333, 'فم': 3523, 'باذن': 1380, 'تخسيس': 1692, 'و': 4781, 'ازاله': 246, 'تسمي': 1767, 'شعر': 2983, 'بشر': 1501, 'تكثيف': 1901, 'لحا': 3849, 'البهاق': 708, 'القدره': 994, 'الجنسيه': 772, 'صدر': 3062, 'رياض': 2702, 'مهبل': 4476, 'تجاعيد': 1636, 'سكر': 2848, 'ضغط': 3138, 'قول': 3659, 'المعده': 1106, 'مثل': 4030, 'رجال': 2628, 'ناس': 4567, 'انواع': 1299, 'أوجد': 80, 'مكن': 4398, 'مع': 4300, 'تقدم': 1879, 'زمن': 2737, 'في': 3543, 'شخص': 2955, 'كفى': 3737, 'كل': 3738, 'شي': 3028, 'موت': 4500, 'ما': 3934, 'لجن': 3847, 'انشاء': 1272, 'الكبيره': 1009, 'محن': 4090, 'زايد': 2721, 'احتاج': 155, 'تدخل': 1707, 'كي': 3775, 'سر': 2815, 'تام': 1615, 'جاد': 2068, 'فقط': 3516, 'كتاب': 3709, 'فويس': 3542, 'بوب': 1559, 'كار': 3683, 'ك': 3672, 'لاين': 3841, 'خاص': 2358, 'شاتي': 2927, 'سناب': 2877, 'حمل': 2326, 'شها': 3008, 'نار': 4565, 'عنف': 3370, 'اعتراف': 390, 'فضفض': 3508, 'سعود': 2831, 'بحرين': 1452, 'كويتي': 3774, 'خليج': 2425, 'اغتصاب': 413, 'واتس': 4782, 'ايمو': 1362, 'مطلق': 4293, 'مساج': 4186, 'تومبوي': 2024, 'ضعة': 3135, 'مشكل': 4254, 'عاطف': 3228, 'صباح': 3046, 'انا': 1231, 'شمس': 3006, 'لحى': 3855, 'حظ': 2282, 'قوي': 3662, 'ب': 1367, 'نقاط': 4661, 'صلى': 3094, 'جرب': 2106, 'حصول': 2275, 'رابط': 2592, 'البشره': 700, 'بها': 1554, 'طرق': 3169, 'حصل': 2274, 'بيضاء': 1590, 'رحم': 2639, 'مجموع': 4045, 'تنحيف': 1958, 'لاطفال': 3813, 'عبار': 3243, 'مكمل': 4397, 'غذاء': 3405, 'تسريع': 1762, 'عملة': 3354, 'حرق': 2252, 'دهون': 2535, 'أعال': 43, 'بعطي': 1515, 'لك': 3886, 'كلم': 3744, 'طريق': 3170, 'تعالي': 1822, 'حفر': 2285, 'ندوب': 4607, 'مشاكل': 4239, 'راسل': 2601, 'كم': 3748, 'سوري': 2898, 'خم': 2430, 'مهمة': 4481, 'صعب': 3073, 'وقت': 4919, 'تحدي': 1659, 'مد': 4114, 'ابطال': 102, 'حساب': 2266, 'منع': 4463, 'تساقط': 1754, 'مكان': 4391, 'ضمان': 3141, 'ل': 3783, 'قلا': 3638, 'تعب': 1826, 'اذا': 215, 'لق': 3875, 'اسم': 333, 'مفيد': 4364, 'شرب': 2961, 'جميع': 2146, 'حت': 2224, 'قبل': 3586, 'انتهاء': 1252, 'عرض': 3281, 'حاج': 2195, 'مساعد': 4191, 'بغى': 1519, 'معي': 4341, 'شتر': 2950, 'بيت': 1580, 'محتاج': 4059, 'لاد': 3797, 'ختا': 2372, 'هم': 4761, 'بعث': 1511, 'مخيم': 4113, 'ساعد': 2771, 'سد': 2810, 'تخلص': 1699, 'لسم': 3864, 'عشر': 3300, 'سعر': 2830, 'مناسب': 4430, 'تب': 1621, 'تطلب': 1811, 'نزول': 4614, 'عظام': 3310, 'حياج': 2342, 'رسل': 2654, 'طول': 3197, 'عبر': 3253, 'الخاص': 808, 'عطا': 3307, 'فضل': 3509, 'مثال': 4028, 'قياس': 3664, 'ماء': 3935, 'رجيم': 2634, 'تخفيف': 1698, 'وري': 4889, 'صحه': 3055, 'لذيذ': 3860, 'صف ...
# [8.41344272 7.31483044 7.92793491 ... 7.78483407 7.54844529 8.54697412]

# %%
df[2:15]
# Out:
#                                            Cleaned Text  ...                                      Cleaned Text2
# 33    نتمني لكم يوم سعيد     هنا الافضل    لا لترد  ...  ...  نتمني لكم يوم سعيد هنا الافضل لا تردي اهلا سهل...
# 34    منتج السعادهالزوجيه  الان الان السعاده هنا الق...  ...  منتج السعادهالزوجيه ال ال السعاده هنا لقا هنال...
# 36    هنا راحتك     العلاج الافضل   اهلا وسهلا بكم ا...  ...  هنا راح علاج الافضل اهلا سهل بكم اصدقائي حي صح...
# 37    بتعاني من زياده الوزن والكرش او الترهلات عنا م...  ...  بتع من زياد وزن كرش او ترهل عن منتج طبيعة مضمو...
# 38    قطره الاثاره النسائيه  تعمل علي زياده الرغبه و...  ...  قطر الاثاره النسائيه عمل علي زياد الرغبه لمح ع...
# 39    منتج تكبير وتطويل وتضخيم القضيب يعمل علي قوه و...  ...  منتج تكبير تطويل تضخيم قضيب عمل علي قوى شد انت...
# 51    علكه الاثاره النسائيه  تعمل علي زياده الرغبه و...  ...  علك الاثاره النسائيه عمل علي زياد الرغبه لمح ع...
# 3167  باذن اله المنتجان تعجبكم  تخسيس و ازاله الكرش ...  ...  باذن لها منتج تعجب تخسيس و ازاله كرش و تسمي شع...
# 3168  السلام عليكم عندي منتجات طبيعيه مثل  تخسيس و ا...  ...  سلام على عند منتج طبيعة مثل تخسيس و ازاله كرش ...
# 3184  السلام عليكم عندي منتجات طبيعيه مثل  تخسيس و ا...  ...  سلام على عند منتج طبيعة مثل تخسيس و ازاله كرش ...
# 3187  الناس انواع يوجد الي مكن ينساه مع تقدم الزمن و...  ...  ناس انواع أوجد ال مكن نس مع تقدم زمن في ناس نس...
# 3188                                 في الجنه انشاء اله  ...                                   في لجن انشاء لها
# 3189  الكبيره وعندها برود جنسي او محنه زايده وتحتاج ...  ...  الكبيره عند برود جنس او محن زايد احتاج علاج طب...
# 3190  المتزوجه وعندها برود جنسي او محنه زايده وتحتاج...  ...  المتزوجه عند برود جنس او محن زايد احتاج علاج ط...
# 3191  الي عندها برود جنسي او محنه زايده وتحتاج علاج ...  ...  ال عند برود جنس او محن زايد احتاج علاج طبيعة ت...
#
# [15 rows x 3 columns]

# %%
df.to_csv('df.csv', encoding='utf-8')

# %%
vector_list = vectorizer.transform(text)

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
oversample = SMOTE()
X, y = oversample.fit_resample(vector_list, pd.Categorical(df.iloc[:,-1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### **Train Test Split**

# %%
import numpy as np
unique, counts = np.unique(y, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 11034, 1: 11034}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 14)

# %%
print('Train size',len(y_train))
print('Test Size' , len(y_test))
# Out:
# Train size 17654
# Test Size 4414

# %% [markdown]
# ###**Feature Extraction**

# %% [markdown]
# ###**Build The Models**

# %%
from sklearn import model_selection, naive_bayes, svm,neural_network,linear_model
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score
# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(X_train,y_train)
# predict the labels on validation dataset
predictions_NB = Naive.predict(X_test)
# Use accuracy_score function to get the accuracy
#print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)
print("Naive Bayes Precision Score -> ",precision_score(predictions_NB, y_test)*100)
print("Naive Bayes Recall Score -> ",recall_score(predictions_NB, y_test)*100)
print("Naive Bayes F1 Score -> ",f1_score(predictions_NB, y_test)*100)
# Out:
# Naive Bayes Precision Score ->  99.40202391904323
# Naive Bayes Recall Score ->  99.44776806258628
# Naive Bayes F1 Score ->  99.42489072923854

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train,y_train)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(X_test)
# Use accuracy_score function to get the accuracy
#print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
print("SVM Precision Score -> ",precision_score(predictions_SVM, y_test)*100)
print("SVM Recall Score -> ",recall_score(predictions_SVM, y_test)*100)
print("SVM F1 Score -> ",f1_score(predictions_SVM, y_test)*100)
# Out:
# SVM Precision Score ->  99.77000919963201
# SVM Recall Score ->  99.67830882352942
# SVM F1 Score ->  99.72413793103449

# %%
# Classifier - Algorithm - NN
# fit the training dataset on the classifier
NN = neural_network.MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=100)
NN.fit(X_train,y_train)
# predict the labels on validation dataset
predictions_NN = NN.predict(X_test)
# Use accuracy_score function to get the accuracy
#print("NN Accuracy Score -> ",accuracy_score(predictions_NN, Test_Y)*100)
print("NN Precision Score -> ",precision_score(predictions_NN, y_test)*100)
print("NN Recall Score -> ",recall_score(predictions_NN, y_test)*100)
print("NN F1 Score -> ",f1_score(predictions_NN, y_test)*100)
# Out:
# NN Precision Score ->  99.90800367985281
# NN Recall Score ->  99.40503432494279
# NN F1 Score ->  99.65588437715071
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
# Classifier - Algorithm - LR
# fit the training dataset on the classifier
LR = linear_model.LogisticRegression()
LR.fit(X_train,y_train)
# predict the labels on validation dataset
predictions_LR = LR.predict(X_test)
# Use accuracy_score function to get the accuracy
#print("LR Accuracy Score -> ",accuracy_score(predictions_LR, Test_Y)*100)
print("LR Precision Score -> ",precision_score(predictions_LR, y_test)*100)
print("LR Recall Score -> ",recall_score(predictions_LR, y_test)*100)
print("LR F1 Score -> ",f1_score(predictions_LR, y_test)*100)
# Out:
# LR Precision Score ->  97.28610855565776
# LR Recall Score ->  99.71711456859971
# LR F1 Score ->  98.48661233993015
